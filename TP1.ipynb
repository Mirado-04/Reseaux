# %% [markdown]
# ## SAE 12
# __Groupe 8__
# - JAOFERSON Andriamirado
# - JACATON Paul
# - ZACCARO Tristan
# - LEFEBVRE Hugo
#
# _**Documentation**_
#
# Équipements :
# - les switchs
# - les machines (ordinateurs)
# - les câbles
# - le routeur
#
# Réseaux :
# masque de sous réseaux 255.255.255.0 /24
#
# - Administrateur IPv4 : 192.168.10 | Passerelle : 192.168.10.1
# - Personnel IPv4 : 192.168.20 | Passerelle : 192.168.20.1
# - Production IPv4 : 192.168.30 | Passerelle : 192.168.30.1
# - Video IPv4 : 192.168.40 | Passerelle : 192.168.40.1
